# %%
import sys
from pathlib import Path

sys.path.append(str(Path().resolve().parent))
from pipe.sales import principal
df = principal(source = 'API')
df
# Out:
#                      Api Versao CnpjInstituicao  \
# 0     canais_atendimento  2.0.1  11760553000169
# 1     canais_atendimento  2.0.1  00966246000112
# 2     canais_atendimento  2.0.1  04243780000151
# 3     canais_atendimento  2.0.1  25606237000141
# 4     canais_atendimento  2.0.1  66788142000173
# ...                  ...    ...             ...
# 8349              pilar3  1.2.0  07237373000120
# 8350              pilar3  1.2.0  07237373000120
# 8351              pilar3  1.2.0  07237373000120
# 8352              pilar3  1.2.0  07237373000120
# 8353              pilar3  1.2.0  07237373000120
#
#                      NomeInstituicao                   NomeContato  \
# 0                GAZINCRED S.A. SCFI           Riscos e Compliance
# 1                     CC CREDICERIPA                   Arquitetura
# 2                 CCC BRASIL CENTRAL                   Arquitetura
# 3       CPC LIV ADM DO VALE RIO DOCE                   Arquitetura
# ...
